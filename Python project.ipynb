# %%
print("Welcome to my game (The rabbit)")
field=[["🌿", "🌿", "🌿"], ["🌿", "🌿", "🌿"], ["🌿", "🌿", "🌿"]]
print(f"{field[0]}\n{field[1]}\n{field[2]}")
print("\nWhere you want the  go ?🐑")
position=input("Enter the row and column")
row=int(position[0])
column=int(position[1])
field[row-1][column-1]="🐑"
print("===========================")
print(f"{field[0]}\n{field[1]}\n{field[2]}")
# Out:
# Welcome to my game (The rabbit)
# ['🌿', '🌿', '🌿']
# ['🌿', '🌿', '🌿']
# ['🌿', '🌿', '🌿']
#
# Where you want the rabbit go ?🐇
# Enter the row and column 21
# ...
# ['🌿', '🌿', '🌿']
# ['🐇', '🌿', '🌿']
# ['🌿', '🌿', '🌿']
